# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
df = pd.read_csv('teste.csv', sep='|')

# %%
dfa = df[:3]

# %% [markdown]
# dfa

# %%
dfa[:3]

# %%
frame = DataFrame(df)

# %%
for i,linha in frame.iterrows():
    if linha ['Department'] == 'POLICE':
        linha['Department'] = 'teste'
        #frame.to_csv('teste2.csv', sep=',')
        #print(linha)
        print(linha)

# %%
frame.Department == 'POLICE'

# %%
ale = frame.loc[(frame['Department'] == 'POLICE')]

# %%
for i, linha in ale.iterrows():
    print(i)

# %%
ale
# Out:
#        Unnamed: 0                    Name  \
# 1               1       AARON,  JEFFERY M
# 2               2          AARON,  KARINA
# 9               9        ABBATE,  TERRY M
# 11             11       ABBOTT,  LYNISE M
# 13             13         ABDALLAH,  ZAID
# 14             14   ABDELHADI,  ABDALMAHD
# 16             16      ABDELMAJEID,  AZIZ
# 21             21    ABDULLAH,  LAKENYA N
# 24             24       ABEJERO,  JASON V
# 31             31       ABRAHAM,  NANCY A
# 34             34        ABRAMS,  HENRY L
# 44             44           ABRON,  FLOYD
# 46             46        ABSTON,  KATHY A
# 48             48        ABUDAYEH,  ELIAS
# 51             51    ABUZANAT,  ABDALLA H
# 53             53    ACCARDO,  JENNIFER A
# 54             54      ACCARDO,  THOMAS J
# 58             58       ACEVEDO,  AARON F
# 59             59   ACEVEDO,  ALEJANDRO R
# 60             60    ACEVEDO,  BIENVENIDO
# 61             61      ACEVEDO,  CLARISSA
# ...

# %%
frame
# Out:
#        Unnamed: 0                      Name  \
# 0               0           AARON,  ELVIA J
# 1               1         AARON,  JEFFERY M
# 2               2            AARON,  KARINA
# 3               3       AARON,  KIMBERLEI R
# 4               4       ABAD JR,  VICENTE M
# 5               5           ABARCA,  ANABEL
# 6               6         ABARCA,  EMMANUEL
# 7               7     ABBATACOLA,  ROBERT J
# 8               8     ABBATEMARCO,  JAMES J
# 9               9          ABBATE,  TERRY M
# 10             10          ABBOTT,  BETTY L
# 11             11         ABBOTT,  LYNISE M
# 12             12    ABBRUZZESE,  WILLIAM J
# 13             13           ABDALLAH,  ZAID
# 14             14     ABDELHADI,  ABDALMAHD
# 15             15       ABDELLATIF,  AREF R
# 16             16        ABDELMAJEID,  AZIZ
# 17             17       ABDOLLAHZADEH,  ALI
# 18             18  ABDUL-KARIM,  MUHAMMAD A
# 19             19       ABDULLAH,  DANIEL N
# ...

# %%
ale = frame.loc[(frame['Department']=='POLICE')]
ale2 = frame.loc[(frame['Department']=='WATER MGMNT')]
ale3 = frame.loc[(frame['Department']=='teste_alessandro')]
ale4 = frame.loc[(frame['Position Title'] == 'POLICE OFFICER')]
ale5 = frame.loc[(frame['Department'] == 'NOVO TESTE')]

for i, linha in ale.iterrows():
    frame.loc[i,'Department'] = 'teste_alessandro'
    
for ind, l in ale2.iterrows():
    frame.loc[ind,'Department'] = 'NOVOTESTE-RIO'
    
for ind2,l in ale3.iterrows():
    frame.loc[ind2,'Department'] = 'MAIS TESTE ALESSANDRO'  
    
for ind3,l in ale4.iterrows():
    frame.loc[ind3,'Position Title'] = 'POLICE OFFICER_TESTE'

for ind4,l in ale5.iterrows():
    frame.loc[ind4, 'Department'] = 'NOVO_REGISTRO_CLIENTE'
    
frame
# Out:
#        Unnamed: 0                      Name  \
# 0               0           AARON,  ELVIA J
# 1               1         AARON,  JEFFERY M
# 2               2            AARON,  KARINA
# 3               3       AARON,  KIMBERLEI R
# 4               4       ABAD JR,  VICENTE M
# 5               5           ABARCA,  ANABEL
# 6               6         ABARCA,  EMMANUEL
# 7               7     ABBATACOLA,  ROBERT J
# 8               8     ABBATEMARCO,  JAMES J
# 9               9          ABBATE,  TERRY M
# 10             10          ABBOTT,  BETTY L
# 11             11         ABBOTT,  LYNISE M
# 12             12    ABBRUZZESE,  WILLIAM J
# 13             13           ABDALLAH,  ZAID
# 14             14     ABDELHADI,  ABDALMAHD
# 15             15       ABDELLATIF,  AREF R
# 16             16        ABDELMAJEID,  AZIZ
# 17             17       ABDOLLAHZADEH,  ALI
# 18             18  ABDUL-KARIM,  MUHAMMAD A
# 19             19       ABDULLAH,  DANIEL N
# ...
